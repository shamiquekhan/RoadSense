# %% [markdown]
# # 08 Visualisation
#
# Build the ministry-ready interactive map from the scored segment exports.

# %%
from src.visualise import build_priority_map

build_priority_map('outputs/geojson/all_segments_scored.gpkg', 'outputs/maps/roadsense_priority_map.html')
