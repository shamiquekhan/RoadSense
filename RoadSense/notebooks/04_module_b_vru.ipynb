# %% [markdown]
# # 04 Module B - VRU Exposure
#
# Estimate where vulnerable road users are most exposed through attractors, population, conflict, and PTW context.

# %%
from src.module_b import run

run()
