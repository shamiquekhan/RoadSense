# %% [markdown]
# # 07 Evaluation
#
# Run the validation checks for spatial autocorrelation, module consistency, and sensitivity analysis.

# %%
from src.evaluation import run_evaluation

run_evaluation()
