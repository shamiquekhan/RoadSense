# %% [markdown]
# # 01 Data Exploration
#
# Use this notebook to audit raw datasets, check schema coverage, and confirm the project inputs are ready before preprocessing.

# %%
from src.utils import audit_datasets

audit_datasets('data/raw')
